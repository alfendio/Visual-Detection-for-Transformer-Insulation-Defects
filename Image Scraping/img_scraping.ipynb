# %%
pip install bing-image-downloader

# %%
from bing_image_downloader import downloader

downloader.download("insulation pressboard transformer", limit = 50, output_dir = 'D:/Dataset TA Baru', adult_filter_off = True)
# Out:
# [%] Downloading Images to D:\Dataset TA Baru\insulation pressboard transformer
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://image.made-in-china.com/2f0j00EBZtDVaKHCrO/Electrical-Insulation-Pressboard-for-Transformer.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://5.imimg.com/data5/EN/FI/UM/SELLER-3756681/pre-compressed-pressboard-500x500.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://4.imimg.com/data4/GQ/TN/MY-18507255/transformer-insulation-kit-500x500.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://sc01.alicdn.com/kf/HTB1HoVISVXXXXXgXVXXq6xXFXXXc/231106855/HTB1HoVISVXXXXXgXVXXq6xXFXXXc.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://image.made-in-china.com/2f0j00lCPtSJnMQvpA/Insulation-Pressboard-Transformer.jpg
# [%] File Downloaded !
#
# ...

# %%
# !zip -r /content/LM35.zip /content/LM35
